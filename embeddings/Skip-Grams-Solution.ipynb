# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %%
print(len(train_words), len(int_words), round(len(train_words)/len(int_words),2))
# Out:
# 4626440 16680599 0.28

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6525 0.0344 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6307 0.0300 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5234 0.0302 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6133 0.0286 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5465 0.0299 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5356 0.0302 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5577 0.0302 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5438 0.0294 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4871 0.0311 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4173 0.0286 sec/batch
# Nearest to use: spikes, homographs, cura, irs, herman, continua, mediums, odegard,
# Nearest to five: mirabeau, viability, lagos, presuming, aloe, obrenovic, relinquishment, hebrew,
# Nearest to also: maneuvers, generalizations, urbana, eisteddfod, slovenians, dispassionate, earmarked, letsie,
# Nearest to more: repudiating, fittingly, buff, mesures, predicate, jerrold, icrm, ecclesiastica,
# Nearest to so: professorship, stepping, ultrasparc, interrogative, macedon, aggravating, heuristic, callet,
# Nearest to called: signifier, moruroa, postmillennial, menzies, headed, renounce, cassatt, maggots,
# Nearest to will: prods, trope, navarre, hebe, francophone, tleilaxu, das, avenging,
# Nearest to world: palahniuk, wooded, alicia, sullivan, unusual, oscillation, belgrano, klement,
# Nearest to running: offshore, portable, mandaean, kitakyushu, bylaws, narrates, ambidextrous, earmarked,
# Nearest to account: westphalia, protested, detention, again, meitnerium, misurasata, sympathies, rivest,
# Nearest to active: burkert, reflects, lasts, courant, melt, poto, aaliyah, drover,
# Nearest to ice: republicanism, occultist, popularized, aquarii, ncr, virology, frontiers, consultation,
# Nearest to something: intermediates, pharyngealized, laments, guangxi, derivates, propositional, backstreet, alvis,
# Nearest to engine: bumpy, quinoa, prizren, bri, nuremberg, fillings, mannerism, enfield,
# Nearest to arts: feeling, dazed, commanders, keefe, tasted, killian, abrogate, holbach,
# Nearest to centre: lycomedes, preslav, hornsby, posture, deity, dostoyevsky, workshops, avail,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5048 0.0311 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4080 0.0288 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3526 0.0295 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2631 0.0279 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2279 0.0316 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1659 0.0294 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1185 0.0291 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0573 0.0281 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9961 0.0294 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9985 0.0305 sec/batch
# Nearest to use: spikes, circuits, strengths, possessed, cura, homographs, herman, mediums,
# Nearest to five: works, lagos, hebrew, mirabeau, viability, practised, freeze, relinquishment,
# Nearest to also: generalizations, maneuvers, knowledge, eisteddfod, earmarked, odd, lisa, anglo,
# Nearest to more: massive, free, predicate, repudiating, grade, uniform, wives, mesures,
# Nearest to so: stepping, interrogative, professorship, following, macedon, ultrasparc, surrounded, aggravating,
# Nearest to called: signifier, headed, companies, goods, peninsula, numbers, component, moruroa,
# Nearest to will: navarre, fame, trope, hebe, das, undergraduate, francophone, pagans,
# Nearest to world: unusual, palahniuk, major, regular, wooded, sullivan, frequently, globe,
# Nearest to running: portable, offshore, narrates, sight, role, screen, earmarked, mid,
# Nearest to account: again, protested, whatever, rivest, meitnerium, sympathies, inventor, westphalia,
# Nearest to active: reflects, burkert, lasts, coast, generic, organizations, courant, melt,
# Nearest to ice: republicanism, consultation, popularized, evaluation, rock, occultist, frontiers, coat,
# Nearest to something: uses, band, intermediates, propositional, variance, strategy, laments, threads,
# Nearest to engine: bumpy, nuremberg, quinoa, mannerism, climates, wiener, porter, enfield,
# Nearest to arts: feeling, commanders, explore, dazed, business, abrogate, keefe, killian,
# Nearest to centre: supplies, posture, deity, lycomedes, spellings, diluted, workshops, detain,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9509 0.0303 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8896 0.0282 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8782 0.0300 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8665 0.0305 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8164 0.0299 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8083 0.0291 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8059 0.0303 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7941 0.0303 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7792 0.0305 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7863 0.0300 sec/batch
# Nearest to use: spikes, homographs, circuits, strengths, unix, cura, railroads, mediums,
# Nearest to five: hebrew, mirabeau, works, three, presuming, viability, lagos, practised,
# Nearest to also: generalizations, maneuvers, eisteddfod, earmarked, knowledge, urbana, eastenders, odd,
# Nearest to more: massive, repudiating, free, contemplate, buff, predicate, rural, uniform,
# Nearest to so: professorship, interrogative, stepping, macedon, ultrasparc, heuristic, aggravating, banning,
# Nearest to called: signifier, headed, moruroa, goods, brethren, jokes, menzies, peninsula,
# Nearest to will: francophone, navarre, countryside, trope, das, tertiary, tleilaxu, blasted,
# Nearest to world: palahniuk, wooded, unusual, major, intense, belgrano, oscillation, sullivan,
# Nearest to running: offshore, portable, narrates, sight, earmarked, bylaws, punishing, rails,
# Nearest to account: again, westphalia, whatever, protested, detention, sympathies, rivest, charismatic,
# Nearest to active: burkert, reflects, lasts, generic, courant, melt, chippewa, coast,
# Nearest to ice: republicanism, occultist, popularized, frontiers, coat, rock, consultation, musicologist,
# Nearest to something: intermediates, propositional, strategy, variance, laments, threads, band, uses,
# Nearest to engine: bumpy, nuremberg, mannerism, wiener, quinoa, climates, bri, enfield,
# Nearest to arts: feeling, dazed, commanders, explore, business, abrogate, waveform, shootout,
# Nearest to centre: posture, deity, supplies, diluted, windows, lycomedes, dostoyevsky, spellings,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7722 0.0311 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7596 0.0303 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7323 0.0291 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6967 0.0296 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7214 0.0303 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6901 0.0288 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7065 0.0296 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7352 0.0302 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6856 0.0293 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6950 0.0281 sec/batch
# Nearest to use: homographs, irs, spikes, unix, railroads, strengths, mitigating, dust,
# Nearest to five: three, zero, eight, seven, singer, one, mirabeau, six,
# Nearest to also: generalizations, maneuvers, urbana, eisteddfod, earmarked, eastenders, knowledge, odd,
# Nearest to more: massive, contemplate, predicate, repudiating, uniform, mesures, rural, buff,
# Nearest to so: professorship, stepping, interrogative, heuristic, ultrasparc, aggravating, mole, nod,
# Nearest to called: signifier, moruroa, discord, jokes, menzies, headed, renounce, goods,
# Nearest to will: francophone, trope, tleilaxu, navarre, blasted, tertiary, countryside, declensions,
# Nearest to world: palahniuk, major, wooded, unusual, ellesmere, intense, globe, arrested,
# Nearest to running: offshore, portable, narrates, bylaws, kitakyushu, punishing, earmarked, ambidextrous,
# Nearest to account: again, sympathies, westphalia, detention, protested, proxy, whatever, meitnerium,
# Nearest to active: burkert, reflects, lasts, generic, courant, melt, chippewa, monmouth,
# Nearest to ice: republicanism, occultist, popularized, frontiers, coat, ibiblio, rock, musicologist,
# Nearest to something: intermediates, propositional, laments, strategy, uses, variance, threads, coll,
# Nearest to engine: bumpy, nuremberg, wiener, bri, prizren, mannerism, quinoa, endo,
# Nearest to arts: feeling, dazed, commanders, explore, abrogate, waveform, business, shootout,
# Nearest to centre: posture, lycomedes, vanguard, deity, diluted, avail, dostoyevsky, supplies,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6873 0.0308 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6702 0.0297 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5963 0.0305 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6265 0.0297 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6215 0.0286 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6479 0.0292 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6071 0.0228 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5666 0.0305 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5170 0.0294 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5187 0.0298 sec/batch
# Nearest to use: unix, homographs, irs, spikes, circuits, strengths, mitigating, traffic,
# Nearest to five: three, zero, eight, seven, singer, one, six, mirabeau,
# Nearest to also: generalizations, maneuvers, urbana, eisteddfod, earmarked, slovenians, odd, eastenders,
# Nearest to more: contemplate, predicate, repudiating, uniform, massive, buff, immigrating, mesures,
# Nearest to so: interrogative, professorship, ultrasparc, heuristic, nod, stepping, aggravating, banning,
# Nearest to called: signifier, moruroa, jokes, discord, maggots, kinnear, menzies, goods,
# Nearest to will: trope, francophone, tleilaxu, blasted, tertiary, talent, avenging, trajectory,
# Nearest to world: major, palahniuk, wooded, unusual, ellesmere, intense, national, belgrano,
# Nearest to running: offshore, portable, ambidextrous, bylaws, kitakyushu, screen, earmarked, punishing,
# Nearest to account: sympathies, westphalia, detention, again, protested, whatever, charismatic, meitnerium,
# Nearest to active: burkert, reflects, lasts, courant, generic, chippewa, melt, swamps,
# Nearest to ice: republicanism, occultist, bmi, ibiblio, musicologist, popularized, coat, rock,
# Nearest to something: intermediates, propositional, laments, uses, strategy, variance, criticism, pharyngealized,
# Nearest to engine: bumpy, nuremberg, wiener, prizren, bri, quinoa, enfield, endo,
# Nearest to arts: dazed, feeling, explore, business, abrogate, waveform, commanders, killian,
# Nearest to centre: posture, avail, lycomedes, dostoyevsky, vanguard, diluted, preslav, supplies,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5127 0.0315 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4810 0.0294 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4567 0.0307 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5319 0.0305 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4990 0.0259 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4754 0.0291 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4832 0.0317 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4101 0.0289 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4017 0.0277 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4210 0.0299 sec/batch
# Nearest to use: circuits, unix, homographs, irs, spikes, disjoint, traffic, mitigating,
# Nearest to five: zero, three, seven, eight, mirabeau, presuming, six, mankiewicz,
# Nearest to also: maneuvers, generalizations, eisteddfod, urbana, slovenians, odd, earmarked, knowledge,
# Nearest to more: predicate, buff, contemplate, massive, colors, immigrating, uniform, options,
# Nearest to so: ultrasparc, heuristic, interrogative, professorship, superfamily, axes, mole, encoding,
# Nearest to called: signifier, numbers, maggots, discord, moruroa, jokes, outward, kinnear,
# Nearest to will: trope, tleilaxu, francophone, blasted, tertiary, could, talent, trajectory,
# Nearest to world: major, palahniuk, ellesmere, national, intense, wooded, casper, jal,
# Nearest to running: offshore, portable, ambidextrous, bylaws, screen, buggy, punishing, silkworm,
# Nearest to account: sympathies, charismatic, detention, westphalia, whatever, protested, again, meitnerium,
# Nearest to active: burkert, lasts, reflects, chippewa, courant, generic, swamps, aaliyah,
# Nearest to ice: republicanism, bmi, occultist, ibiblio, coat, herc, rock, musicologist,
# Nearest to something: uses, intermediates, propositional, laments, variance, backstreet, strategy, band,
# Nearest to engine: bumpy, nuremberg, rodents, enfield, quinoa, automobiles, wiener, prizren,
# Nearest to arts: dazed, feeling, explore, abrogate, waveform, business, shaivism, comprehensive,
# Nearest to centre: avail, preslav, dostoyevsky, vanguard, lycomedes, posture, supplies, diluted,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4470 0.0308 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3964 0.0302 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4439 0.0314 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3932 0.0300 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3953 0.0294 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4596 0.0307 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3853 0.0297 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3933 0.0300 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4198 0.0294 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3596 0.0302 sec/batch
# Nearest to use: circuits, homographs, disjoint, irs, unix, mitigating, traffic, continua,
# Nearest to five: three, zero, eight, seven, one, six, mankiewicz, mirabeau,
# Nearest to also: maneuvers, generalizations, eisteddfod, urbana, python, earmarked, letters, slovenians,
# Nearest to more: massive, predicate, immigrating, colors, contemplate, rural, uniform, options,
# Nearest to so: ultrasparc, heuristic, interrogative, mole, superfamily, nod, axes, encoding,
# Nearest to called: signifier, maggots, moruroa, discord, outward, postmillennial, jokes, present,
# Nearest to will: trope, tleilaxu, blasted, seconds, pagans, spate, induce, avenging,
# Nearest to world: major, palahniuk, intense, national, ellesmere, casper, unusual, jal,
# Nearest to running: portable, offshore, ambidextrous, screen, bylaws, silkworm, fouquet, buggy,
# Nearest to account: whatever, westphalia, charismatic, sympathies, detention, protested, honeydew, exerting,
# Nearest to active: burkert, lasts, reflects, generic, courant, swamps, monmouth, flex,
# Nearest to ice: republicanism, bmi, ibiblio, coat, occultist, herc, rock, popularized,
# Nearest to something: intermediates, uses, propositional, threads, laments, criticism, strategy, divert,
# Nearest to engine: bumpy, automobiles, rodents, wiener, enfield, fillings, endo, nuremberg,
# Nearest to arts: dazed, feeling, explore, business, abrogate, comprehensive, waveform, shaivism,
# Nearest to centre: avail, vanguard, lycomedes, preslav, dostoyevsky, posture, supplies, raya,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.4059 0.0333 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4096 0.0318 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3522 0.0300 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3733 0.0297 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3923 0.0291 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3738 0.0297 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3832 0.0300 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3970 0.0291 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3296 0.0291 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3200 0.0308 sec/batch
# Nearest to use: circuits, homographs, irs, unix, mitigating, disjoint, continua, models,
# Nearest to five: three, zero, seven, eight, one, six, mankiewicz, two,
# Nearest to also: generalizations, maneuvers, urbana, eisteddfod, slovenians, earmarked, filename, odd,
# Nearest to more: massive, immigrating, rural, fittingly, predicate, options, contemplate, buff,
# Nearest to so: interrogative, ultrasparc, mole, professorship, convince, sticky, nod, stepping,
# Nearest to called: signifier, moruroa, maggots, discord, postmillennial, present, outward, fips,
# Nearest to will: tleilaxu, trope, seconds, avenging, blasted, tertiary, know, could,
# Nearest to world: major, palahniuk, ellesmere, national, intense, jal, casper, impeached,
# Nearest to running: portable, offshore, ambidextrous, silkworm, screen, bylaws, mattel, fouquet,
# Nearest to account: charismatic, sympathies, westphalia, macromolecule, whatever, detention, exerting, honeydew,
# Nearest to active: burkert, lasts, locate, aaliyah, melt, reflects, swamps, generic,
# Nearest to ice: republicanism, bmi, rock, coat, herc, ibiblio, nutritionists, fuga,
# Nearest to something: propositional, intermediates, laments, uses, pharyngealized, criticism, backstreet, threads,
# Nearest to engine: automobiles, bumpy, rodents, herstory, mfm, bri, fillings, wiener,
# Nearest to arts: dazed, feeling, explore, business, comprehensive, abrogate, shootout, killer,
# Nearest to centre: avail, lycomedes, preslav, dostoyevsky, vanguard, posture, supplies, guinean,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3793 0.0313 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2811 0.0303 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3763 0.0283 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3552 0.0295 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3749 0.0303 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3052 0.0289 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2891 0.0285 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3383 0.0300 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2332 0.0297 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2984 0.0294 sec/batch
# Nearest to use: circuits, homographs, unix, irs, disjoint, mitigating, continua, traffic,
# Nearest to five: three, zero, seven, one, eight, six, two, four,
# Nearest to also: generalizations, urbana, eisteddfod, maneuvers, odd, bayezid, filename, letsie,
# Nearest to more: massive, immigrating, rural, fittingly, repudiating, raves, propose, options,
# Nearest to so: interrogative, ultrasparc, convince, sticky, heuristic, utamaro, axes, nod,
# Nearest to called: moruroa, maggots, signifier, postmillennial, kinnear, jokes, present, fips,
# Nearest to will: tleilaxu, trope, seconds, blasted, avenging, suspect, francophone, to,
# Nearest to world: major, palahniuk, ellesmere, temperamental, unusual, intense, casper, jal,
# Nearest to running: portable, silkworm, ambidextrous, screen, offshore, mattel, fouquet, bylaws,
# Nearest to account: charismatic, westphalia, sympathies, detention, whatever, exerting, rivest, macromolecule,
# Nearest to active: burkert, lasts, monmouth, locate, aaliyah, generic, idb, levitation,
# Nearest to ice: republicanism, bmi, coat, herc, ibiblio, rock, musicologist, occultist,
# Nearest to something: propositional, intermediates, threads, laments, pharyngealized, uses, alvis, strategy,
# Nearest to engine: automobiles, bumpy, rodents, herstory, mfm, wiener, endo, bri,
# Nearest to arts: dazed, business, comprehensive, explore, feeling, abrogate, shaivism, waveform,
# Nearest to centre: avail, vanguard, lycomedes, preslav, dostoyevsky, raya, posture, guinean,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3154 0.0322 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2821 0.0314 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3198 0.0141 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2509 0.0288 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2163 0.0300 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2085 0.0294 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2490 0.0303 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1866 0.0296 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2260 0.0297 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1978 0.0291 sec/batch
# Nearest to use: circuits, homographs, unix, commercialization, traffic, disjoint, irs, continua,
# Nearest to five: three, zero, one, seven, six, eight, two, mankiewicz,
# Nearest to also: urbana, eisteddfod, maneuvers, generalizations, slovenians, odd, bayezid, efta,
# Nearest to more: massive, immigrating, rural, options, fittingly, repudiating, raves, defenses,
# Nearest to so: interrogative, ultrasparc, convince, nod, axes, sticky, hamper, stepping,
# Nearest to called: moruroa, signifier, maggots, postmillennial, tusks, kinnear, present, jokes,
# Nearest to will: tleilaxu, trope, avenging, blasted, seconds, regiments, suspect, trajectory,
# Nearest to world: major, palahniuk, ellesmere, boasts, jal, temperamental, intense, unusual,
# Nearest to running: portable, screen, ambidextrous, silkworm, mattel, offshore, buggy, decompression,
# Nearest to account: sympathies, charismatic, whatever, westphalia, exerting, detention, honeydew, rivest,
# Nearest to active: burkert, locate, lasts, idb, melt, levitation, generic, aaliyah,
# Nearest to ice: republicanism, herc, coat, bmi, ibiblio, rock, popularized, musicologist,
# Nearest to something: propositional, laments, criticism, pharyngealized, threads, asks, alvis, divert,
# Nearest to engine: automobiles, rodents, bumpy, herstory, mfm, endo, fillings, fitted,
# Nearest to arts: dazed, business, comprehensive, explore, feeling, abrogate, art, shaivism,
# Nearest to centre: avail, vanguard, lycomedes, preslav, dostoyevsky, raya, supplies, hearse,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2248 0.0316 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2096 0.0296 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2154 0.0284 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1172 0.0291 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1800 0.0308 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1707 0.0297 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1791 0.0282 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1939 0.0303 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1969 0.0300 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1575 0.0303 sec/batch
# Nearest to use: homographs, circuits, commercialization, fodder, continua, mitigating, irs, organisations,
# Nearest to five: three, zero, seven, one, eight, six, two, four,
# Nearest to also: urbana, generalizations, maneuvers, eisteddfod, slovenians, odd, sinless, impact,
# Nearest to more: massive, immigrating, rural, options, performance, fittingly, raves, propose,
# Nearest to so: interrogative, axes, ultrasparc, ohka, nod, heuristic, pinching, sticky,
# Nearest to called: moruroa, maggots, signifier, present, postmillennial, hypothesizing, initialization, discord,
# Nearest to will: tleilaxu, trope, seconds, engels, know, could, avenging, suspect,
# Nearest to world: major, ellesmere, palahniuk, boasts, jal, centred, intense, federations,
# Nearest to running: portable, screen, ambidextrous, mattel, offshore, silkworm, buggy, decompression,
# Nearest to account: sympathies, whatever, westphalia, exerting, honeydew, charismatic, detention, rivest,
# Nearest to active: burkert, locate, idb, lasts, monmouth, aaliyah, implantation, muscovite,
# Nearest to ice: republicanism, coat, herc, bmi, ibiblio, freezing, popularized, rock,
# Nearest to something: propositional, alvis, threads, divert, pharyngealized, laments, asks, smelled,
# Nearest to engine: automobiles, bumpy, herstory, endo, rodents, mfm, fitted, wiener,
# Nearest to arts: dazed, business, art, explore, comprehensive, universities, abrogate, feeling,
# Nearest to centre: avail, vanguard, preslav, dostoyevsky, lycomedes, subway, wielkopolska, raya,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1688 0.0300 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2437 0.0302 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1679 0.0288 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1670 0.0289 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1862 0.0308 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1867 0.0280 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2173 0.0299 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1752 0.0305 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1638 0.0297 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1579 0.0316 sec/batch
# Nearest to use: homographs, circuits, commercialization, fodder, continua, mitigating, unix, organisations,
# Nearest to five: three, zero, one, seven, six, eight, two, four,
# Nearest to also: urbana, generalizations, maneuvers, eisteddfod, odd, slovenians, sinless, impact,
# Nearest to more: massive, immigrating, options, rural, propose, fittingly, performance, raves,
# Nearest to so: interrogative, nod, ultrasparc, axes, sticky, convince, stepping, ohka,
# Nearest to called: moruroa, maggots, signifier, present, postmillennial, tusks, component, initialization,
# Nearest to will: tleilaxu, seconds, trope, avenging, know, engels, regiments, suspect,
# Nearest to world: ellesmere, major, palahniuk, boasts, jal, intense, unusual, federations,
# Nearest to running: portable, ambidextrous, offshore, mattel, buggy, silkworm, screen, fouquet,
# Nearest to account: sympathies, rivest, macromolecule, exerting, honeydew, whatever, meitnerium, protested,
# Nearest to active: locate, burkert, idb, levitation, lasts, aaliyah, monmouth, organizations,
# Nearest to ice: coat, bmi, republicanism, popularized, herc, rock, ibiblio, freezing,
# Nearest to something: propositional, threads, alvis, pharyngealized, divert, criticism, uses, conditional,
# Nearest to engine: automobiles, bumpy, heinz, herstory, endo, bri, wiener, rodents,
# Nearest to arts: business, dazed, art, explore, comprehensive, universities, abrogate, feeling,
# Nearest to centre: avail, vanguard, lycomedes, preslav, dostoyevsky, subway, wielkopolska, weekday,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2039 0.0324 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1495 0.0283 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1866 0.0302 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1728 0.0285 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1439 0.0295 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1466 0.0294 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.2016 0.0316 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1055 0.0281 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2019 0.0303 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2078 0.0299 sec/batch
# Nearest to use: homographs, circuits, unix, continua, commercialization, organisations, telecommunication, fodder,
# Nearest to five: three, zero, one, six, seven, eight, two, four,
# Nearest to also: urbana, slovenians, eisteddfod, maneuvers, odd, generalizations, briar, sinless,
# Nearest to more: massive, rural, repudiating, fittingly, immigrating, raves, propose, options,
# Nearest to so: interrogative, stepping, convince, sticky, utamaro, nod, surrounded, aggravating,
# Nearest to called: moruroa, maggots, postmillennial, present, signifier, discord, danielle, gign,
# Nearest to will: tleilaxu, know, avenging, regiments, engels, trope, seconds, suspect,
# Nearest to world: ellesmere, palahniuk, major, boasts, gervasio, federations, intense, temperamental,
# Nearest to running: portable, ambidextrous, offshore, mattel, buggy, silkworm, decompression, screen,
# Nearest to account: exerting, macromolecule, meitnerium, sympathies, rivest, detention, whatever, honeydew,
# Nearest to active: idb, lasts, locate, monmouth, burkert, levitation, aaliyah, organizations,
# Nearest to ice: herc, coat, republicanism, bmi, popularized, ibiblio, belfry, musicologist,
# Nearest to something: alvis, propositional, pharyngealized, threads, uses, laments, divert, smelled,
# Nearest to engine: automobiles, bumpy, endo, bri, wiener, herstory, heinz, rodents,
# Nearest to arts: business, dazed, art, universities, explore, comprehensive, bachelor, journalism,
# Nearest to centre: avail, vanguard, lycomedes, preslav, dostoyevsky, subway, weekday, wielkopolska,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2427 0.0302 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1408 0.0293 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1507 0.0285 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1465 0.0280 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0449 0.0299 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1226 0.0285 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1639 0.0297 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1575 0.0299 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1930 0.0064 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0944 0.0302 sec/batch
# Nearest to use: homographs, circuits, commercialization, continua, ascii, unix, interoperable, fodder,
# Nearest to five: three, zero, one, seven, six, two, eight, four,
# Nearest to also: urbana, generalizations, eisteddfod, slovenians, odd, sinless, briar, filename,
# Nearest to more: massive, rural, raves, repudiating, options, propose, performance, immigrating,
# Nearest to so: interrogative, utamaro, convince, sticky, nod, stepping, ultrasparc, heuristic,
# Nearest to called: moruroa, maggots, danielle, postmillennial, signifier, tusks, jokes, lys,
# Nearest to will: seconds, tleilaxu, avenging, know, regiments, trope, engels, hobbyists,
# Nearest to world: ellesmere, palahniuk, major, boasts, temperamental, federations, unusual, intense,
# Nearest to running: buggy, portable, ambidextrous, decompression, offshore, screen, mattel, fouquet,
# Nearest to account: exerting, sympathies, macromolecule, detention, meitnerium, rivest, lifeless, astronomy,
# Nearest to active: monmouth, lasts, idb, locate, organizations, aaliyah, burkert, contravention,
# Nearest to ice: herc, bmi, republicanism, popularized, coat, ibiblio, musicologist, belfry,
# Nearest to something: alvis, propositional, pharyngealized, strategy, threads, divert, saying, honest,
# Nearest to engine: automobiles, bumpy, endo, bri, heinz, wiener, herstory, transports,
# Nearest to arts: art, business, dazed, universities, explore, comprehensive, journalism, beaux,
# Nearest to centre: avail, weekday, subway, vanguard, lycomedes, preslav, institute, outlying,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0749 0.0317 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0587 0.0286 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0769 0.0303 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0554 0.0299 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0779 0.0284 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0603 0.0299 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0856 0.0291 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0948 0.0296 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1147 0.0288 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0376 0.0305 sec/batch
# Nearest to use: homographs, fodder, circuits, commercialization, organisations, intelligently, disjoint, unix,
# Nearest to five: three, zero, one, seven, six, two, eight, four,
# Nearest to also: urbana, slovenians, eisteddfod, odd, maneuvers, impact, generalizations, yavapai,
# Nearest to more: massive, rural, raves, middle, aller, performance, propose, immigrating,
# Nearest to so: interrogative, surrounded, utamaro, pinching, sticky, axes, convince, disgrace,
# Nearest to called: moruroa, postmillennial, maggots, present, danielle, signifier, valid, principalities,
# Nearest to will: seconds, avenging, know, tleilaxu, regiments, twine, suspect, macbook,
# Nearest to world: ellesmere, palahniuk, major, boasts, federations, gervasio, temperamental, leonov,
# Nearest to running: buggy, ambidextrous, decompression, portable, offshore, screen, mattel, dvorak,
# Nearest to account: exerting, sympathies, lifeless, meitnerium, rivest, hiding, detention, westphalia,
# Nearest to active: locate, idb, levitation, lasts, organizations, monmouth, patch, aaliyah,
# Nearest to ice: herc, republicanism, bmi, popularized, coat, ibiblio, northeast, musicologist,
# Nearest to something: alvis, propositional, divert, uses, pharyngealized, threads, honest, amniocentesis,
# Nearest to engine: automobiles, bumpy, heinz, endo, bri, transports, turboprop, wiener,
# Nearest to arts: art, business, dazed, universities, comprehensive, explore, bachelor, beaux,
# Nearest to centre: avail, preslav, lycomedes, subway, weekday, quds, vanguard, pend,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0215 0.0304 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0335 0.0295 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0042 0.0294 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0595 0.0296 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0985 0.0294 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0544 0.0305 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0711 0.0295 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0916 0.0303 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0577 0.0310 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0432 0.0301 sec/batch
# Nearest to use: circuits, homographs, organisations, intelligently, commercialization, interoperable, unix, fodder,
# Nearest to five: zero, three, six, two, one, seven, four, eight,
# Nearest to also: urbana, generalizations, slovenians, odd, eisteddfod, impact, yavapai, engelbart,
# Nearest to more: rural, massive, astute, raves, middle, performance, propose, aller,
# Nearest to so: interrogative, surrounded, sticky, pinching, gigo, ultrasparc, exhausted, utamaro,
# Nearest to called: moruroa, danielle, maggots, present, postmillennial, a, separating, component,
# Nearest to will: seconds, know, avenging, tleilaxu, macbook, then, to, inhibit,
# Nearest to world: major, ellesmere, boasts, ultimate, palahniuk, federations, unusual, intense,
# Nearest to running: buggy, decompression, ambidextrous, offshore, earmarked, fouquet, portable, lydon,
# Nearest to account: exerting, astronomy, lifeless, astrophysical, macromolecule, predictions, sympathies, meitnerium,
# Nearest to active: idb, locate, lasts, implantation, aaliyah, patch, levitation, organizations,
# Nearest to ice: herc, republicanism, bmi, popularized, musicologist, coat, northeast, ibiblio,
# Nearest to something: alvis, uses, propositional, divert, threads, pharyngealized, strategy, categorically,
# Nearest to engine: automobiles, bumpy, heinz, endo, turboprop, herstory, wiener, bri,
# Nearest to arts: art, business, dazed, universities, comprehensive, explore, beaux, quadrivium,
# Nearest to centre: avail, preslav, weekday, lycomedes, outlying, wielkopolska, institute, subway,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0817 0.0299 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0961 0.0294 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1069 0.0299 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0596 0.0295 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0683 0.0296 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0944 0.0302 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0800 0.0303 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0454 0.0310 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0764 0.0300 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0671 0.0288 sec/batch
# Nearest to use: homographs, circuits, commercialization, intelligently, organisations, disjoint, interoperable, continua,
# Nearest to five: zero, three, one, seven, two, six, four, eight,
# Nearest to also: slovenians, urbana, generalizations, eisteddfod, devaluation, odd, filename, engelbart,
# Nearest to more: massive, rural, propose, raves, astute, middle, fittingly, aller,
# Nearest to so: interrogative, surrounded, exhausted, utamaro, convince, stepping, nod, gigo,
# Nearest to called: moruroa, maggots, postmillennial, present, forms, brussels, tusks, separating,
# Nearest to will: seconds, know, tleilaxu, avenging, macbook, you, generalities, trope,
# Nearest to world: ellesmere, major, boasts, ultimate, palahniuk, federations, leonov, war,
# Nearest to running: buggy, offshore, decompression, ambidextrous, earmarked, portable, fouquet, mattel,
# Nearest to account: astronomy, exerting, predictions, lifeless, astrophysical, rivest, macromolecule, sympathies,
# Nearest to active: idb, locate, patch, lasts, monmouth, implantation, levitation, organizations,
# Nearest to ice: herc, republicanism, popularized, bmi, northeast, musicologist, selector, paleocene,
# Nearest to something: alvis, uses, propositional, pharyngealized, divert, honest, threads, coll,
# Nearest to engine: automobiles, heinz, bumpy, bri, turboprop, wiener, endo, foresaw,
# Nearest to arts: art, business, dazed, universities, beaux, comprehensive, bachelor, explore,
# Nearest to centre: avail, weekday, preslav, lycomedes, institute, vanguard, wielkopolska, subway,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0609 0.0303 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0083 0.0284 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0281 0.0300 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0657 0.0289 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0669 0.0291 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1398 0.0294 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1207 0.0292 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0470 0.0294 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0079 0.0278 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0793 0.0291 sec/batch
# Nearest to use: intelligently, homographs, interoperable, commercialization, organisations, circuits, strengths, telecommunication,
# Nearest to five: zero, three, seven, one, two, six, eight, four,
# Nearest to also: slovenians, urbana, odd, eisteddfod, filename, generalizations, devaluation, engelbart,
# Nearest to more: massive, raves, rural, middle, propose, astute, immigrating, trema,
# Nearest to so: interrogative, utamaro, convince, surrounded, gigo, exhausted, stepping, entendres,
# Nearest to called: moruroa, lys, principalities, maggots, danielle, brussels, postmillennial, present,
# Nearest to will: seconds, know, tleilaxu, avenging, macbook, you, generalities, inhibit,
# Nearest to world: ultimate, ellesmere, federations, palahniuk, boasts, temperamental, major, war,
# Nearest to running: buggy, decompression, ambidextrous, offshore, fouquet, earmarked, emulates, lain,
# Nearest to account: astronomy, exerting, monmouth, lifeless, astrophysical, meitnerium, qnx, detention,
# Nearest to active: idb, patch, monmouth, locate, organizations, lasts, courant, aaliyah,
# Nearest to ice: republicanism, northeast, herc, popularized, selector, bmi, freezing, paleocene,
# Nearest to something: alvis, propositional, uses, pharyngealized, divert, honest, coll, threads,
# Nearest to engine: automobiles, bumpy, heinz, bri, turboprop, surrendering, wiener, endo,
# Nearest to arts: art, business, universities, dazed, beaux, bachelor, journalism, athletic,
# Nearest to centre: lycomedes, avail, preslav, weekday, institute, quds, outlying, pend,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9857 0.0306 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0387 0.0285 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0323 0.0294 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0451 0.0302 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0571 0.0300 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0552 0.0305 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0495 0.0305 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9926 0.0306 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0090 0.0300 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9626 0.0297 sec/batch
# Nearest to use: intelligently, homographs, commercialization, interoperable, strengths, interoperability, telecommunication, users,
# Nearest to five: zero, three, one, six, two, seven, four, eight,
# Nearest to also: urbana, odd, eisteddfod, generalizations, slovenians, exaggerates, engelbart, videotape,
# Nearest to more: massive, rural, middle, raves, astute, immigrating, propose, options,
# Nearest to so: interrogative, surrounded, convince, gigo, exhausted, utamaro, swabia, gesserit,
# Nearest to called: moruroa, for, maggots, principalities, lys, postmillennial, danielle, issachar,
# Nearest to will: seconds, know, avenging, tleilaxu, inhibit, macbook, you, induce,
# Nearest to world: ultimate, ellesmere, boasts, federations, palahniuk, intense, temperamental, rushmore,
# Nearest to running: buggy, decompression, ambidextrous, portable, offshore, cpus, lydon, earmarked,
# Nearest to account: lifeless, astronomy, exerting, monmouth, astrophysical, bunnies, meitnerium, rivest,
# Nearest to active: monmouth, lasts, idb, patch, locate, aaliyah, structuralism, implantation,
# Nearest to ice: republicanism, northeast, herc, popularized, bmi, freezing, selector, occultist,
# Nearest to something: alvis, uses, propositional, pharyngealized, divert, honest, spices, coll,
# Nearest to engine: automobiles, turboprop, bumpy, heinz, bri, surrendering, foresaw, wiener,
# Nearest to arts: art, beaux, universities, dazed, business, martial, bachelor, quadrivium,
# Nearest to centre: weekday, outlying, preslav, subway, quds, institute, avail, lycomedes,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9812 0.0317 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9750 0.0294 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0417 0.0294 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0107 0.0297 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0221 0.0292 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0102 0.0291 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9249 0.0286 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9735 0.0305 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9141 0.0274 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9830 0.0277 sec/batch
# Nearest to use: homographs, intelligently, organisations, disjoint, strengths, commercialization, fodder, polyamory,
# Nearest to five: zero, three, one, six, two, seven, four, eight,
# Nearest to also: odd, slovenians, eisteddfod, urbana, generalizations, exaggerates, devaluation, policing,
# Nearest to more: middle, rural, massive, smarteiffel, astute, races, raves, propose,
# Nearest to so: interrogative, surrounded, gigo, gesserit, pinching, propane, exhausted, sticky,
# Nearest to called: for, moruroa, a, issachar, principalities, maggots, danielle, wine,
# Nearest to will: seconds, know, avenging, tleilaxu, inhibit, macbook, you, tertiary,
# Nearest to world: ultimate, boasts, ellesmere, federations, palahniuk, temperamental, war, celebrating,
# Nearest to running: decompression, ambidextrous, buggy, earmarked, offshore, lydon, screen, osteoclasts,
# Nearest to account: astronomy, lifeless, astrophysical, exerting, bunnies, rivest, monmouth, predictions,
# Nearest to active: lasts, patch, idb, monmouth, organizations, implantation, locate, structuralism,
# Nearest to ice: republicanism, northeast, herc, bmi, selector, popularized, pdm, ambient,
# Nearest to something: alvis, uses, propositional, divert, pharyngealized, honest, spices, coll,
# Nearest to engine: automobiles, bumpy, turboprop, heinz, bri, surrendering, foresaw, endo,
# Nearest to arts: art, beaux, universities, business, dazed, bachelor, martial, quadrivium,
# Nearest to centre: preslav, weekday, outlying, subway, avail, quds, institute, pend,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9884 0.0302 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9792 0.0289 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9906 0.0300 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9991 0.0289 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0071 0.0294 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9486 0.0288 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9973 0.0286 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9903 0.0289 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9912 0.0291 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0098 0.0288 sec/batch
# Nearest to use: intelligently, homographs, organisations, interoperable, commercialization, disjoint, users, strengths,
# Nearest to five: zero, three, one, two, six, eight, seven, four,
# Nearest to also: urbana, eisteddfod, odd, videotape, engelbart, slovenians, generalizations, disorganised,
# Nearest to more: rural, smarteiffel, astute, massive, middle, raves, modernist, races,
# Nearest to so: interrogative, surrounded, gigo, gesserit, exhausted, nod, stepping, entendres,
# Nearest to called: issachar, for, moruroa, maggots, a, wine, discord, principalities,
# Nearest to will: seconds, know, macbook, avenging, tleilaxu, inhibit, go, furlongs,
# Nearest to world: ultimate, federations, war, ellesmere, palahniuk, boasts, leonov, frieze,
# Nearest to running: decompression, buggy, earmarked, ambidextrous, lydon, oratorios, fouquet, screen,
# Nearest to account: astronomy, astrophysical, exerting, lifeless, rivest, predictions, monmouth, macromolecule,
# Nearest to active: patch, lasts, aaliyah, organizations, monmouth, implantation, courant, idb,
# Nearest to ice: republicanism, herc, northeast, selector, bmi, popularized, ambient, belfry,
# Nearest to something: alvis, uses, pharyngealized, propositional, honest, divert, spices, truth,
# Nearest to engine: automobiles, bumpy, turboprop, bri, heinz, wiener, foresaw, endo,
# Nearest to arts: art, beaux, universities, dazed, business, bachelor, martial, crafts,
# Nearest to centre: weekday, preslav, outlying, institute, subway, quds, outdoor, avail,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9861 0.0292 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9936 0.0292 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9729 0.0283 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0084 0.0289 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0113 0.0300 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0072 0.0291 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0131 0.0296 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9864 0.0281 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9563 0.0283 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0413 0.0313 sec/batch
# Nearest to use: interoperable, organisations, commercialization, intelligently, disjoint, interoperability, strengths, homographs,
# Nearest to five: zero, three, six, one, two, seven, eight, four,
# Nearest to also: devaluation, generalizations, urbana, slovenians, promote, filename, odd, videotape,
# ...
# Nearest to use: uses, used, for, markus, intelligently, disjoint, organisations, effective,
# Nearest to five: two, one, zero, four, six, three, seven, eight,
# Nearest to also: of, as, see, by, an, and, to, the,
# Nearest to more: than, while, to, smarteiffel, are, much, often, middle,
# Nearest to so: understand, gemination, propane, exhausted, combinations, i, gpmg, following,
# Nearest to called: a, for, in, as, forms, are, which, connected,
# Nearest to will: furlongs, difference, this, inhibit, predicts, israelite, devotions, you,
# Nearest to world: ultimate, war, rawlings, boasts, countries, top, federations, hovercraft,
# Nearest to running: decompression, zeon, rusher, criticise, whitney, oratorios, runs, hong,
# Nearest to account: astrophysical, lander, document, liff, astronomy, eclipsing, predictions, confusion,
# Nearest to active: patch, hydrozoa, sporting, lineage, gather, sink, parochial, infinitive,
# Nearest to ice: republicanism, melts, hockey, materialize, delmarva, scenario, ambient, reassessment,
# Nearest to something: things, divert, truth, nothing, vocations, doubtful, honest, alvis,
# Nearest to engine: turboprop, cylinder, foresaw, exhaust, bumpy, wiener, engines, gearbox,
# Nearest to arts: art, beaux, bachelor, martial, budo, sparring, painters, disciplines,
# Nearest to centre: preslav, institute, upmarket, posture, pianists, dame, wielkopolska, artefact,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7976 0.0319 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8775 0.0302 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8803 0.0283 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8757 0.0294 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8692 0.0299 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8795 0.0309 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8700 0.0299 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8416 0.0311 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8614 0.0300 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.9002 0.0319 sec/batch
# Nearest to use: used, uses, markus, for, intelligently, interoperable, disjoint, lexicographers,
# Nearest to five: two, zero, one, four, six, three, seven, eight,
# Nearest to also: of, as, see, by, to, an, the, ghidorah,
# Nearest to more: than, while, smarteiffel, to, are, modernist, middle, often,
# Nearest to so: understand, exhausted, who, gemination, propane, i, dreamed, couldn,
# Nearest to called: a, for, in, which, forms, as, are, caribbean,
# Nearest to will: furlongs, israelite, devotions, difference, this, predicts, inhibit, escap,
# Nearest to world: war, ultimate, eight, countries, boasts, rawlings, hovercraft, federations,
# Nearest to running: decompression, zeon, criticise, hong, provides, oratorios, whitney, rusher,
# Nearest to account: astrophysical, astronomy, lander, document, confusion, liff, eclipsing, predictions,
# Nearest to active: patch, hydrozoa, lineage, sporting, sink, gather, infinitive, contravention,
# Nearest to ice: republicanism, melts, materialize, hockey, scenario, iceberg, reassessment, belfry,
# Nearest to something: things, divert, truth, honest, nothing, doubtful, vocations, stiller,
# Nearest to engine: turboprop, cylinder, foresaw, exhaust, wiener, bumpy, gearbox, instituted,
# Nearest to arts: art, beaux, bachelor, martial, budo, disciplines, sparring, judo,
# Nearest to centre: preslav, institute, upmarket, dame, posture, wielkopolska, pianists, quds,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8596 0.0305 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8161 0.0306 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8253 0.0300 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8176 0.0292 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8953 0.0297 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8200 0.0303 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9738 0.0296 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8903 0.0294 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8973 0.0278 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8233 0.0292 sec/batch
# Nearest to use: uses, used, markus, for, intelligently, disjoint, ritchie, effective,
# Nearest to five: two, zero, one, four, six, three, seven, eight,
# Nearest to also: of, as, see, by, the, an, in, ghidorah,
# Nearest to more: than, while, to, middle, often, are, modernist, and,
# Nearest to so: understand, who, dreamed, exhausted, gemination, propane, but, following,
# Nearest to called: a, as, for, in, forms, which, this, are,
# Nearest to will: furlongs, israelite, inhibit, this, predicts, difference, devotions, escap,
# Nearest to world: war, ultimate, eight, countries, rawlings, top, united, gervasio,
# Nearest to running: decompression, zeon, hong, criticise, provides, whitney, abilene, oratorios,
# Nearest to account: astrophysical, lander, document, astronomy, confusion, eclipsing, untaet, liff,
# Nearest to active: patch, hydrozoa, lineage, infinitive, sporting, coterminous, keenly, sink,
# Nearest to ice: republicanism, melts, hockey, materialize, iceberg, kool, herc, delmarva,
# Nearest to something: things, divert, vocations, honest, doubtful, nothing, truth, coll,
# Nearest to engine: turboprop, cylinder, foresaw, exhaust, wiener, bumpy, gearbox, bri,
# Nearest to arts: art, beaux, bachelor, martial, budo, judo, sparring, disciplines,
# Nearest to centre: preslav, institute, upmarket, pianists, posture, wielkopolska, lycomedes, quds,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8047 0.0314 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8625 0.0300 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7838 0.0294 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8629 0.0286 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8412 0.0308 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8476 0.0291 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8536 0.0200 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8497 0.0308 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8149 0.0308 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8680 0.0295 sec/batch
# Nearest to use: used, uses, markus, intelligently, lexicographers, effective, disjoint, misnomer,
# Nearest to five: two, one, zero, four, six, three, seven, eight,
# Nearest to also: of, as, see, by, an, in, s, fugees,
# Nearest to more: than, middle, while, to, often, are, much, modernist,
# Nearest to so: understand, propane, dreamed, gemination, but, who, exhausted, convince,
# Nearest to called: a, as, for, in, which, forms, this, are,
# Nearest to will: furlongs, israelite, inhibit, predicts, difference, devotions, this, know,
# Nearest to world: ultimate, top, countries, war, rawlings, albania, boasts, contradictions,
# Nearest to running: decompression, zeon, criticise, provides, rusher, hong, buggy, runs,
# Nearest to account: astrophysical, lander, eclipsing, confusion, document, liff, astronomy, lifeless,
# Nearest to active: patch, hydrozoa, lineage, infinitive, gather, sink, sporting, coterminous,
# Nearest to ice: republicanism, hockey, melts, materialize, iceberg, kool, northeast, arctic,
# Nearest to something: things, divert, nothing, vocations, alvis, doubtful, honest, coll,
# Nearest to engine: foresaw, turboprop, cylinder, exhaust, wiener, gearbox, bumpy, rodents,
# Nearest to arts: art, beaux, martial, budo, bachelor, sparring, judo, eskrima,
# Nearest to centre: preslav, posture, upmarket, institute, pianists, dame, quds, lycomedes,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8216 0.0311 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8264 0.0302 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8105 0.0306 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8334 0.0297 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8478 0.0288 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8145 0.0286 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8855 0.0296 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7534 0.0297 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8467 0.0289 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7824 0.0302 sec/batch
# Nearest to use: used, uses, markus, for, effective, intelligently, polyamory, and,
# Nearest to five: two, zero, one, four, six, three, seven, eight,
# Nearest to also: of, as, by, a, see, and, an, is,
# Nearest to more: than, middle, while, to, much, are, often, smarteiffel,
# Nearest to so: propane, understand, i, gemination, exhausted, gpmg, dreamed, but,
# Nearest to called: a, for, which, in, as, this, are, of,
# Nearest to will: inhibit, furlongs, israelite, difference, predicts, this, you, i,
# Nearest to world: countries, war, ultimate, top, eight, rawlings, boasts, united,
# Nearest to running: decompression, zeon, criticise, provides, whitney, rusher, osteoclasts, hong,
# Nearest to account: lander, document, astrophysical, confusion, astronomy, eclipsing, liff, abridged,
# Nearest to active: patch, hydrozoa, sporting, gather, lineage, infinitive, keenly, coterminous,
# Nearest to ice: republicanism, northeast, hockey, materialize, melts, arctic, kool, iceberg,
# Nearest to something: divert, things, nothing, doubtful, stiller, vocations, truth, alvis,
# Nearest to engine: turboprop, foresaw, cylinder, exhaust, gearbox, bumpy, wiener, bri,
# Nearest to arts: art, beaux, martial, bachelor, budo, sparring, judo, eskrima,
# Nearest to centre: preslav, posture, upmarket, pianists, dame, welding, quds, institute,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7638 0.0302 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8174 0.0299 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8774 0.0289 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8270 0.0307 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8135 0.0293 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9112 0.0286 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8231 0.0291 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8367 0.0302 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8231 0.0303 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8606 0.0285 sec/batch
# Nearest to use: uses, used, for, effective, markus, and, polyamory, intelligently,
# Nearest to five: two, zero, four, one, six, three, seven, eight,
# Nearest to also: of, as, see, by, the, an, a, and,
# Nearest to more: than, while, to, are, middle, often, and, much,
# Nearest to so: propane, understand, gemination, all, but, i, exhausted, who,
# Nearest to called: a, which, as, in, for, forms, this, usually,
# Nearest to will: furlongs, this, inhibit, difference, israelite, predicts, macbook, blogger,
# Nearest to world: war, ultimate, countries, rawlings, top, eight, albania, contradictions,
# Nearest to running: decompression, zeon, criticise, whitney, oratorios, rusher, osteoclasts, provides,
# Nearest to account: lander, liff, astrophysical, confusion, eclipsing, astronomy, document, abridged,
# Nearest to active: patch, hydrozoa, sporting, lineage, sink, keenly, infinitive, gather,
# Nearest to ice: republicanism, hockey, materialize, northeast, kool, arctic, melts, iceberg,
# Nearest to something: things, divert, nothing, vocations, doubtful, truth, stiller, coll,
# Nearest to engine: foresaw, cylinder, turboprop, exhaust, wiener, engines, rodents, heinz,
# Nearest to arts: art, beaux, bachelor, budo, martial, judo, disciplines, connoisseur,
# Nearest to centre: preslav, posture, institute, dame, upmarket, qualitatively, pianists, welding,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8498 0.0302 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8398 0.0279 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8181 0.0299 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8096 0.0291 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8686 0.0313 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8418 0.0304 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8420 0.0291 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8369 0.0293 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8153 0.0297 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8053 0.0294 sec/batch
# Nearest to use: used, uses, for, effective, an, markus, commonly, and,
# Nearest to five: two, zero, one, four, six, three, seven, eight,
# Nearest to also: of, as, see, a, an, by, to, the,
# Nearest to more: than, to, while, middle, are, and, often, or,
# Nearest to so: propane, but, all, dreamed, who, understand, render, i,
# Nearest to called: a, in, which, as, for, this, of, usually,
# Nearest to will: furlongs, inhibit, israelite, this, predicts, difference, blogger, devotions,
# Nearest to world: war, countries, eight, ultimate, rawlings, top, united, history,
# Nearest to running: decompression, zeon, criticise, provides, hong, whitney, osteoclasts, screen,
# Nearest to account: lander, liff, confusion, astronomy, astrophysical, eclipsing, document, predictions,
# Nearest to active: patch, hydrozoa, sink, sporting, lineage, infinitive, keenly, carlsberg,
# Nearest to ice: republicanism, hockey, iceberg, materialize, kool, northeast, herc, mandolinists,
# Nearest to something: things, divert, doubtful, vocations, stiller, nothing, coll, honest,
# Nearest to engine: cylinder, foresaw, turboprop, engines, exhaust, wiener, bri, heinz,
# Nearest to arts: art, beaux, budo, bachelor, martial, judo, disciplines, eskrima,
# Nearest to centre: preslav, upmarket, posture, institute, dame, welding, pianists, qualitatively,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8545 0.0297 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8192 0.0292 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9360 0.0280 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9257 0.0283 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8932 0.0296 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8016 0.0309 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7937 0.0299 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8529 0.0294 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7741 0.0281 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8425 0.0305 sec/batch
# Nearest to use: uses, used, for, markus, commonly, intelligently, effective, and,
# Nearest to five: two, one, zero, four, six, three, seven, eight,
# Nearest to also: of, as, see, a, an, in, s, to,
# Nearest to more: than, to, while, middle, are, and, often, less,
# Nearest to so: dreamed, render, propane, understand, but, gemination, convince, couldn,
# Nearest to called: a, in, which, as, for, forms, this, usually,
# Nearest to will: furlongs, israelite, difference, inhibit, predicts, this, devotions, macbook,
# Nearest to world: war, top, ultimate, countries, rawlings, eight, united, albania,
# Nearest to running: decompression, zeon, criticise, buggy, whitney, provides, hong, cpus,
# Nearest to account: lander, liff, astrophysical, confusion, document, abridged, astronomy, eclipsing,
# Nearest to active: patch, infinitive, sporting, hydrozoa, sink, as, keenly, lineage,
# Nearest to ice: republicanism, hockey, kool, iceberg, materialize, northeast, mandolinists, reassessment,
# Nearest to something: things, divert, nothing, vocations, doubtful, stiller, coll, truth,
# Nearest to engine: cylinder, turboprop, foresaw, engines, exhaust, wiener, bri, rodents,
# Nearest to arts: art, beaux, budo, martial, bachelor, judo, disciplines, eskrima,
# Nearest to centre: preslav, upmarket, posture, institute, welding, dame, lycomedes, quds,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8303 0.0309 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8016 0.0309 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
